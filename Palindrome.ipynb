# %% [markdown]
# <a href="https://colab.research.google.com/github/Aartikale23/Data_Science_Lab_SE_B_30/blob/main/Palindrome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter a number: "))
temp = num
reverse = 0

while num > 0:
    digit = num % 10
    reverse = reverse * 10 + digit
    num = num // 10

if temp == reverse:
    print("The number is a Palindrome")
else:
    print("The number is NOT a Palindrome")
# Out:
# Enter a number: 121
# The number is a Palindrome
